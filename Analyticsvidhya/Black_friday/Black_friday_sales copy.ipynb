# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import chart_studio as py
import plotly.express as px
import cufflinks as cf

# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Nikhil-V98/Hackathons/main/Analyticsvidhya/Black_friday/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Nikhil-V98/Hackathons/main/Analyticsvidhya/Black_friday/test.csv')

test.fillna(0,inplace=True)
train.fillna(0,inplace=True)

train['Product_Category_2'] = train['Product_Category_2'].astype('int64')
train['Product_Category_3'] = train['Product_Category_3'].astype('int64')

# %%
df =train.loc[:1999]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                   0                   0      8370
# 1                   6                  14     15200
# ...

# %%
px.bar(data_frame=df,x='Age',y='Gender',color='City_Category')
# Out:
# <div>                            <div id="b658c39c-c59c-4542-94e7-750039cf2889" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b658c39c-c59c-4542-94e7-750039cf2889")) {                    Plotly.newPlot(                        "b658c39c-c59c-4542-94e7-750039cf2889",                        [{"alignmentgroup":"True","hovertemplate":"City_Category=A<br>Age=%{x}<br>Gender=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","0-17","0-17","0-17","26-35","26-35","26-35","26-35","26-35","26-35","51-55","51-55","51-55","51-55","26-35","26-35","26-35","26-35","26-35","26-35","26-35","26-35","26-35","0-17","0-17","0-17","0-
# ...
